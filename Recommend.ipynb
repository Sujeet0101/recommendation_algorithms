# %%
import pandas as pd
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# %%
df = pd.read_csv("hosteldata.csv")
df.head(20)
# Out:
#     Hid                    HostelName   District  \
# 0     1          Big Bell Boys Hostel  Bhaktapur
# 1     2           Friends Boys Hostel  Bhaktapur
# 2     3       Golden Gate Boys Hostel  Bhaktapur
# 3     4            Ajima Girls Hostel  Bhaktapur
# 4     5       Manjushree Girls Hostel  Bhaktapur
# 5     6           Swastik Boys Hostel  Bhaktapur
# 6     7       Sweet Home Girls Hostel  Bhaktapur
# 7     8            Pagoda Boys Hostel  Bhaktapur
# 8     9            Subha Girls Hostel  Bhaktapur
# 9    10     Siddhi Laxmi Girls Hostel  Bhaktapur
# 10   11           Krishna Boys Hostel  Bhaktapur
# 11   12  Planet Bhaktapur Boys Hostel  Bhaktapur
# 12   13          Paradise Boys Hostel  Bhaktapur
# 13   14           Kumari Girls Hostel  Bhaktapur
# 14   15             Shiva Boys Hostel  Bhaktapur
# 15   16           Tulaja Girls Hostel  Bhaktapur
# 16   17           Sunny Boys Hostel    Bhaktapur
# 17   18      Hostel Central Bhaktapur  Bhaktapur
# ...

# %%
df = df [['Hid','HostelName','District','Place/City','HostelType','SingleSeater','DoubleSeater','3Seater','4Seater',
         'Description','Wifi','HotWater','Parking','Laundry','CCTV','Fan']]

# %%
df.head()
# Out:
#    Hid               HostelName   District    Place/City HostelType  \
# 0    1     Big Bell Boys Hostel  Bhaktapur  Tibukche Tol       Boys
# 1    2      Friends Boys Hostel  Bhaktapur       Dokchee       Boys
# 2    3  Golden Gate Boys Hostel  Bhaktapur        Talako       Boys
# 3    4       Ajima Girls Hostel  Bhaktapur        Ghakha      Girls
# 4    5  Manjushree Girls Hostel  Bhaktapur      Dudhpati      Girls
#
#    SingleSeater  DoubleSeater  3Seater  4Seater  \
# 0         12000         11000    10000     9000
# 1         11000         10000     9000     8000
# 2         13000         12000    11000    10000
# 3         12000         11000    10000     9000
# 4         12000         11000    10000     9000
#
#                            Description  Wifi  HotWater  Parking  Laundry  \
# 0  This hostel has peacful environment  True      True     True     True
# 1  This hostel has peacful environment  True      True     True     True
# ...
